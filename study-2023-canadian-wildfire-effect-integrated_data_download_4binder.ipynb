# %% [markdown]
# # Study 2023 Canadian Wildfires using TROPESS CrIS JPSS-1 Carbon Monoxide (CO) data products with Integrated Data Download
#
# [![Binder](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/NASA-TROPESS/tutorials_notebooks/2957015d3fc15146c80b9b0f980e59ccdbc15acf?urlpath=lab%2Ftree%2Fstudy-2023-canadian-wildfire-effect-integrated_data_download_4binder.ipynb)
#
# **Summary:**
#
# This code reads **TROPESS CrIS JPSS-1 Carbon Monoxide (CO)** data products for June 2023 and June 2022 directly using HTTPS-based download from **NASA Earthdata (GES DISC)** and makes a monthly average data product and plots and compares each monthly average.
#
# For continued, seamless operation, a **.netrc** file containing an individual user's **NASA Earthdata Login** credentials (not supplied with this notebook) **should** be provided by each user intending to operate this notebook from their own AWS cloud environment; in the event a .netrc file is not provided in advance, this notebook features an interactive prompt for users to manually enter their own credentials (note: the user-entered credentials are one-time use to operate this notebook and are not stored in memory).
#
# Below are the steps to creating a **.netrc** file and approving API-based access to the **NASA GES DISC Archive**. Please note, **Step 2** below is **required** in advance for **all users** to successfully execute this notebook.
#
#   1. Create an **Earthdata Login Account** ([clear here for details](https://urs.earthdata.nasa.gov/users/new))
#   2. Approve access to the **NASA GES DISC Archive** in your Earthdata Login Profile ([click here for details](https://disc.gsfc.nasa.gov/earthdata-login))
#   3. Create/modify a **.netrc** file in your home directory containing your **Earthdata Login** credentials as shown below:
#      <br>`machine urs.earthdata.nasa.gov login <your username> password <your password>`
#
# **Important:** Before execiuting this notebook, please create a **'data'** and an **'images_average'** folder in the working directory of your notebook.
#
# **Other important notes:**
#
#   1. This code was designed and tested **"as-is"** to run directly within either an **AWS cloud-based Jupyter Hub** environment or a local **JupyterLab** environment.
#   2. All dependencies within this notebook are also available in the latest [**environment.yml**](https://github.com/NASA-TROPESS/binders/blob/main/environment.yml) file, which may be **optionally** used alongside this notebook to create, maintain and activate a dedicated conda environment (**tropess-env**) and Python notebook kernel.
#   3. Please "trust" this notebook before executing; this will prevent errors when writing output to your local directory.

# %% [markdown]
# ## Notebook Author / Affiliation
#
# David F. Moroni (david.f.moroni@jpl.nasa.gov) / Jet Propulsion Laboratory, Californa Institute of Technology
#
# ### Date Authored
#
# 19 October 2023
#
# ### Last Updated
#
# 24 May 2024
#
# ### List of Updates since Original Notebook
#
#   1. Create the local output directory paths if they do not already exist.
#   2. Removed requirement to have .netrc file (and credentials) supplied by the user prior to notebook execution.
#   3. Interactive user prompt to enter NASA Earthdata Login credentials (if not already provided in .netrc file).
#   4. Verification of .netrc NASA Earthdata Login credentials.
#   5. Utilization of NASA **earthaccess** Python library functions to support authentication to NASA Earthdata.
#   6. Add timer to all cells.
#   7. Consolidate import statements to the first cell and remove duplicate import statements.
#   8. Updated guidance notes.
#
# ### Collaborators
# Seungwon Lee (seungwon.lee@jpl.nasa.gov) / Jet Propulsion Laboratory, Californa Institute of Technology
#
# ### Acknowledgements
#
# The research was carried out at the Jet Propulsion Laboratory, California Institute of Technology, under a contract with the National Aeronautics and Space Administration (80NM0018D0004). Government sponsorship acknowledged.

# %%
# %%time

import earthaccess
from earthaccess import Auth, Store
auth = Auth()

import os
import datetime
import contextlib

from pathlib import Path

import pandas as pd

import numpy as np
from netCDF4 import Dataset,num2date,date2num

import matplotlib.pyplot as plt

import imageio.v2 as imageio

from mpl_toolkits.basemap import Basemap

from scipy.interpolate import griddata
from scipy.spatial import cKDTree
# Out:
# CPU times: user 1.52 s, sys: 120 ms, total: 1.64 s
# Wall time: 1.44 s

# %% [markdown]
# # Verify Successful Authentication to NASA Earthdata¶
# Prompt for NASA Earthdata Login Credentials (if .netrc file doesn't already exist)
# A .netrc file will be created if it doesn't already exist.

# %%
# %%time

# Using earthacces library to provide interactie authentication.
auth = earthaccess.login(strategy="interactive", persist=True)

auth.login(strategy="netrc")
authvalid = auth.authenticated
print('Authenication Valid =',authvalid)

# The Store() class enables download or access to data and is instantiated with the user's auth instance.
store = Store(auth)
# Out:
# Authenication Valid = True
# CPU times: user 84.2 ms, sys: 19.3 ms, total: 103 ms
# Wall time: 2.21 s

# %% [markdown]
# # Now we will create the local output directory paths if they do not already exist.

# %%
data_dir_check = os.path.isdir('data')
print("Data directory exists: ",data_dir_check)

images_dir_check = os.path.isdir('images_average')
print("Images directory exists: ",images_dir_check)

if data_dir_check != True: os.makedirs('data')
if images_dir_check != True: os.makedirs('images_average')
# Out:
# Data directory exists:  True
# Images directory exists:  True

# %% [markdown]
# # Now we will download the first month of data from June 2023 to a local directory called 'data'.
# This download script is the podaac-data-downloader which requires credentials to authenticate with the NASA Earthdata Login. The download script has to first be installed in the same environment as the notebook. More details here: [https://github.com/NASA-TROPESS/tutorials_notebooks/blob/main/data_subscriber_downloader.md](https://github.com/NASA-TROPESS/tutorials_notebooks/blob/main/data_subscriber_downloader.md)

# %%
# %%time

# !podaac-data-downloader -c TRPSYL2COCRS1FS -d data -p GES_DISC -sd 2023-06-01T00:00:00Z -ed 2023-06-30T23:23:59Z
# Out:
# [2024-05-24 20:53:49,931] {podaac_data_downloader.py:317} INFO - Found 30 total files to download
# [2024-05-24 20:53:54,782] {podaac_data_downloader.py:358} INFO - 2024-05-24 20:53:54.782605 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2023/TROPESS_CrIS-JPSS1_L2_Summary_CO_20230630_MUSES_R1p20_FS_F0p6.nc
# [2024-05-24 20:53:55,799] {podaac_data_downloader.py:358} INFO - 2024-05-24 20:53:55.799039 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2023/TROPESS_CrIS-JPSS1_L2_Summary_CO_20230629_MUSES_R1p20_FS_F0p6.nc
# [2024-05-24 20:53:56,232] {podaac_data_downloader.py:358} INFO - 2024-05-24 20:53:56.232098 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2023/TROPESS_CrIS-JPSS1_L2_Summary_CO_20230628_MUSES_R1p20_FS_F0p6.nc
# [2024-05-24 20:53:57,026] {podaac_data_downloader.py:358} INFO - 2024-05-24 20:53:57.026078 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2023/TROPESS_CrIS-JPSS1_L2_Summary_CO_20230627_MUSES_R1p20_FS_F0p6.nc
# [2024-05-24 20:53:57,654] {podaac_data_downloader.py:358} INFO - 2024-05-24 20:53:57.654516 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2023/TROPESS_CrIS-JPSS1_L2_Summary_CO_20230626_MUSES_R1p20_FS_F0p6.nc
# [2024-05-24 20:53:58,338] {podaac_data_downloader.py:358} INFO - 2024-05-24 20:53:58.338415 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2023/TROPESS_CrIS-JPSS1_L2_Summary_CO_20230625_MUSES_R1p20_FS_F0p6.nc
# [2024-05-24 20:53:58,831] {podaac_data_downloader.py:358} INFO - 2024-05-24 20:53:58.831217 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2023/TROPESS_CrIS-JPSS1_L2_Summary_CO_20230624_MUSES_R1p20_FS_F0p6.nc
# [2024-05-24 20:53:59,369] {podaac_data_downloader.py:358} INFO - 2024-05-24 20:53:59.369113 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2023/TROPESS_CrIS-JPSS1_L2_Summary_CO_20230623_MUSES_R1p20_FS_F0p6.nc
# [2024-05-24 20:53:59,922] {podaac_data_downloader.py:358} INFO - 2024-05-24 20:53:59.922147 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2023/TROPESS_CrIS-JPSS1_L2_Summary_CO_20230622_MUSES_R1p20_FS_F0p6.nc
# [2024-05-24 20:54:00,683] {podaac_data_downloader.py:358} INFO - 2024-05-24 20:54:00.682976 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2023/TROPESS_CrIS-JPSS1_L2_Summary_CO_20230621_MUSES_R1p20_FS_F0p6.nc
# [2024-05-24 20:54:01,398] {podaac_data_downloader.py:358} INFO - 2024-05-24 20:54:01.398348 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2023/TROPESS_CrIS-JPSS1_L2_Summary_CO_20230620_MUSES_R1p20_FS_F0p6.nc
# [2024-05-24 20:54:01,899] {podaac_data_downloader.py:358} INFO - 2024-05-24 20:54:01.899130 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2023/TROPESS_CrIS-JPSS1_L2_Summary_CO_20230619_MUSES_R1p20_FS_F0p6.nc
# [2024-05-24 20:54:02,822] {podaac_data_downloader.py:358} INFO - 2024-05-24 20:54:02.822449 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2023/TROPESS_CrIS-JPSS1_L2_Summary_CO_20230618_MUSES_R1p20_FS_F0p6.nc
# [2024-05-24 20:54:03,243] {podaac_data_downloader.py:358} INFO - 2024-05-24 20:54:03.243172 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2023/TROPESS_CrIS-JPSS1_L2_Summary_CO_20230617_MUSES_R1p20_FS_F0p6.nc
# [2024-05-24 20:54:03,658] {podaac_data_downloader.py:358} INFO - 2024-05-24 20:54:03.658640 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2023/TROPESS_CrIS-JPSS1_L2_Summary_CO_20230616_MUSES_R1p20_FS_F0p6.nc
# [2024-05-24 20:54:04,205] {podaac_data_downloader.py:358} INFO - 2024-05-24 20:54:04.205792 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2023/TROPESS_CrIS-JPSS1_L2_Summary_CO_20230615_MUSES_R1p20_FS_F0p6.nc
# [2024-05-24 20:54:04,833] {podaac_data_downloader.py:358} INFO - 2024-05-24 20:54:04.833487 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2023/TROPESS_CrIS-JPSS1_L2_Summary_CO_20230614_MUSES_R1p20_FS_F0p6.nc
# [2024-05-24 20:54:05,327] {podaac_data_downloader.py:358} INFO - 2024-05-24 20:54:05.327857 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2023/TROPESS_CrIS-JPSS1_L2_Summary_CO_20230613_MUSES_R1p20_FS_F0p6.nc
# [2024-05-24 20:54:05,847] {podaac_data_downloader.py:358} INFO - 2024-05-24 20:54:05.847694 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2023/TROPESS_CrIS-JPSS1_L2_Summary_CO_20230612_MUSES_R1p20_FS_F0p6.nc
# [2024-05-24 20:54:06,398] {podaac_data_downloader.py:358} INFO - 2024-05-24 20:54:06.398800 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2023/TROPESS_CrIS-JPSS1_L2_Summary_CO_20230611_MUSES_R1p20_FS_F0p6.nc
# [2024-05-24 20:54:06,870] {podaac_data_downloader.py:358} INFO - 2024-05-24 20:54:06.869977 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2023/TROPESS_CrIS-JPSS1_L2_Summary_CO_20230610_MUSES_R1p20_FS_F0p6.nc
# [2024-05-24 20:54:07,317] {podaac_data_downloader.py:358} INFO - 2024-05-24 20:54:07.317675 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2023/TROPESS_CrIS-JPSS1_L2_Summary_CO_20230609_MUSES_R1p20_FS_F0p6.nc
# [2024-05-24 20:54:08,061] {podaac_data_downloader.py:358} INFO - 2024-05-24 20:54:08.061327 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2023/TROPESS_CrIS-JPSS1_L2_Summary_CO_20230608_MUSES_R1p20_FS_F0p6.nc
# [2024-05-24 20:54:08,738] {podaac_data_downloader.py:358} INFO - 2024-05-24 20:54:08.738346 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2023/TROPESS_CrIS-JPSS1_L2_Summary_CO_20230607_MUSES_R1p20_FS_F0p6.nc
# [2024-05-24 20:54:09,265] {podaac_data_downloader.py:358} INFO - 2024-05-24 20:54:09.265351 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2023/TROPESS_CrIS-JPSS1_L2_Summary_CO_20230606_MUSES_R1p20_FS_F0p6.nc
# [2024-05-24 20:54:09,774] {podaac_data_downloader.py:358} INFO - 2024-05-24 20:54:09.773950 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2023/TROPESS_CrIS-JPSS1_L2_Summary_CO_20230605_MUSES_R1p20_FS_F0p6.nc
# [2024-05-24 20:54:10,247] {podaac_data_downloader.py:358} INFO - 2024-05-24 20:54:10.246962 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2023/TROPESS_CrIS-JPSS1_L2_Summary_CO_20230604_MUSES_R1p20_FS_F0p6.nc
# [2024-05-24 20:54:10,727] {podaac_data_downloader.py:358} INFO - 2024-05-24 20:54:10.727889 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2023/TROPESS_CrIS-JPSS1_L2_Summary_CO_20230603_MUSES_R1p20_FS_F0p6.nc
# [2024-05-24 20:54:11,316] {podaac_data_downloader.py:358} INFO - 2024-05-24 20:54:11.315967 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2023/TROPESS_CrIS-JPSS1_L2_Summary_CO_20230602_MUSES_R1p20_FS_F0p6.nc
# [2024-05-24 20:54:11,701] {podaac_data_downloader.py:358} INFO - 2024-05-24 20:54:11.701934 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2023/TROPESS_CrIS-JPSS1_L2_Summary_CO_20230601_MUSES_R1p20_FS_F0p6.nc
# [2024-05-24 20:54:11,702] {podaac_data_downloader.py:369} INFO - Downloaded Files: 30
# [2024-05-24 20:54:11,702] {podaac_data_downloader.py:370} INFO - Failed Files:     0
# [2024-05-24 20:54:11,702] {podaac_data_downloader.py:371} INFO - Skipped Files:    0
# [2024-05-24 20:54:11,702] {podaac_data_downloader.py:177} INFO - Success Count: 30
# [2024-05-24 20:54:11,887] {podaac_data_downloader.py:186} INFO - END
#
#
# CPU times: user 453 ms, sys: 99.9 ms, total: 553 ms
# Wall time: 24.7 s

# %% [markdown]
# # Let's read June 2023 daily data products and make a time series and make a monthly average of XCO (colum CO).
# The datasets should be already downloaded in the local directory ./data.
# Please refer to the tutorial about how to download TROPESS datasets from GES DISC.

# %%
# %%time

# Specify date range
start_date = datetime.date(2023, 6, 1)
end_date = datetime.date(2023, 6, 30)

x_col_time_series_2023_june = []

# Loop through the date range and plot Carbon Monoxide for each day
for current_date in pd.date_range(start_date, end_date):
    # Open the netCDF file
    file_date = current_date.strftime("%Y%m%d")
    dataset = Dataset(f'./data/TROPESS_CrIS-JPSS1_L2_Summary_CO_{file_date}_MUSES_R1p20_FS_F0p6.nc', 'r')
    print("reading data from =", file_date)
    
    # Read the data from your variables
    latitude = dataset.variables['latitude'][:]
    longitude = dataset.variables['longitude'][:]
    x_col = dataset.variables['x_col'][:]

    dataset.close()

    # Filter the data for latitude 60S to 80N
    latitude_max = 80.0
    latitude_min = -60.0
    longitude_max = 180.0
    longitude_min = -180.0

    selection_only = np.where(
        (latitude > latitude_min) & (latitude < latitude_max) & 
        (longitude > longitude_min) &(longitude < longitude_max)
    )[0]

    latitude = latitude[selection_only]
    longitude = longitude[selection_only]
    x_col = x_col[selection_only]

    pixel_size_deg = 1.0 # 1 degree resolution

    # Get the grid for the interpolated values
    grid_lat, grid_lon = np.mgrid[-60:81:pixel_size_deg, -180:181:pixel_size_deg]

    # Interpolate the data using griddata
    grid_x_col = griddata((latitude, longitude), x_col, (grid_lat, grid_lon), method='linear', rescale=True)

    # Find the distance to the nearest original point for each point in the interpolated grid
    tree = cKDTree(np.vstack((latitude, longitude)).T)
    dist, _ = tree.query(np.vstack((grid_lat.ravel(), grid_lon.ravel())).T)

    # Reshape the distance array to have the same shape as the x_col grid
    dist_grid = dist.reshape(grid_x_col.shape)

    # Mask the interpolated values that are too far from any original point
    max_distance_degrees = 3.0
    grid_x_col[dist_grid > max_distance_degrees] = np.nan
    
    # Make the time series of daily x_col for one month by appending each day's dataset. 
    x_col_time_series_2023_june.append(grid_x_col)

x_col_time_series_2023_june = np.array(x_col_time_series_2023_june)    
print(x_col_time_series_2023_june.shape)
x_col_month_mean_2023 = np.mean(x_col_time_series_2023_june, axis=0)
# Out:
# reading data from = 20230601
# reading data from = 20230602
# reading data from = 20230603
# reading data from = 20230604
# reading data from = 20230605
# reading data from = 20230606
# reading data from = 20230607
# reading data from = 20230608
# reading data from = 20230609
# reading data from = 20230610
# reading data from = 20230611
# reading data from = 20230612
# reading data from = 20230613
# reading data from = 20230614
# reading data from = 20230615
# reading data from = 20230616
# reading data from = 20230617
# reading data from = 20230618
# reading data from = 20230619
# reading data from = 20230620
# reading data from = 20230621
# reading data from = 20230622
# reading data from = 20230623
# reading data from = 20230624
# reading data from = 20230625
# reading data from = 20230626
# reading data from = 20230627
# reading data from = 20230628
# reading data from = 20230629
# reading data from = 20230630
# (30, 141, 361)
# CPU times: user 32 s, sys: 744 ms, total: 32.8 s
# Wall time: 23.7 s

# %% [markdown]
# # Let's make a global map of the June 2023 averaged XCO using Basemap.

# %%
# %%time

    # Calculate width and height
    aspect_ratio = (longitude_max - longitude_min) / (latitude_max - latitude_min)
    w = 3600; h = w / aspect_ratio

    # Specify figure size (in inches)
    dpi = 300; 
    plt.figure(figsize=(w / dpi, h / dpi))  

    # Create a basemap instance
    m = Basemap(projection='cyl', resolution='l',
                llcrnrlat=-60, urcrnrlat=80,  # set latitude limits to -80 and 80
                llcrnrlon=-180, urcrnrlon=180)  # set longitude limits to -180 and -180

    m.drawmapboundary(fill_color='black')
    m.drawcoastlines(linewidth=0.3, color='white')
    m.drawcountries(linewidth=0.2, color='white')
    #m.drawstates(linewidth=0.2, color='white')


    # Draw parallels (latitude lines) and meridians (longitude lines)
    parallels = np.arange(-60., 81., 20.)
    m.drawparallels(parallels, labels=[True,False,False,False], linewidth=0.3)

    meridians = np.arange(-180., 181., 30.)
    m.drawmeridians(meridians, labels=[False,False,False,True], linewidth=0.3)
    
    pixel_size_deg = 1.0 # 1 degree resolution

    # Get the grid for the interpolated values
    grid_lat, grid_lon = np.mgrid[-60:81:pixel_size_deg, -180:181:pixel_size_deg]

    
    # Plot the interpolated data using pcolormesh instead of scatter
    sc = m.pcolormesh(grid_lon, grid_lat, x_col_month_mean_2023, latlon=True, cmap='jet', alpha=0.7, vmin=60.0, vmax=200.0, shading='auto')
    
    
    # Add a colorbar
    cbar = m.colorbar(sc, location='bottom', pad="10%")
    cbar.set_label('Column-averaged dry-air mixing ratio of carbon monoxide from the surface to Top of Atmosphere (TOA), ppbv')

    # set plot title
    title_date = current_date.strftime("%b-%Y")
    title_min = np.nanmin(x_col_month_mean_2023)
    title_max = np.nanmax(x_col_month_mean_2023)
    plt.title(f'TROPESS - CrIS JPSS-1 - Carbon Monoxide Column (XCO) Month Average - June 2023')
    #\nMin: {title_min:.01f}, Max: {title_max:.01f} ppbv')

    # Save figure to PNG file
    plt.savefig(f'./images_average/TROPESS_Canadian-Fires_CrIS-JPSS-1_XCO_June_2023_month_average.png', dpi=dpi, bbox_inches='tight')

    plt.show()
    plt.close()
# Out:
# CPU times: user 1.49 s, sys: 76.8 ms, total: 1.57 s
# Wall time: 1.97 s

# %% [markdown]
# # Now we will download the second month of data from June 2022 to a local directory called 'data'.
# This download script is the podaac-data-downloader which requires credentials to authenticate with the NASA Earthdata Login. The download script has to first be installed in the same environment as the notebook. More details here: [https://github.com/NASA-TROPESS/tutorials_notebooks/blob/main/data_subscriber_downloader.md](https://github.com/NASA-TROPESS/tutorials_notebooks/blob/main/data_subscriber_downloader.md)

# %%
# %%time

# !podaac-data-downloader -c TRPSYL2COCRS1FS -d data -p GES_DISC -sd 2022-06-01T00:00:00Z -ed 2022-06-30T23:23:59Z
# Out:
# [2024-05-24 20:55:04,543] {podaac_data_downloader.py:317} INFO - Found 30 total files to download
# [2024-05-24 20:55:09,494] {podaac_data_downloader.py:358} INFO - 2024-05-24 20:55:09.494512 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2022/TROPESS_CrIS-JPSS1_L2_Summary_CO_20220630_MUSES_R1p17_FS_F0p6.nc
# [2024-05-24 20:55:10,012] {podaac_data_downloader.py:358} INFO - 2024-05-24 20:55:10.012693 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2022/TROPESS_CrIS-JPSS1_L2_Summary_CO_20220629_MUSES_R1p17_FS_F0p6.nc
# [2024-05-24 20:55:10,523] {podaac_data_downloader.py:358} INFO - 2024-05-24 20:55:10.523918 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2022/TROPESS_CrIS-JPSS1_L2_Summary_CO_20220628_MUSES_R1p17_FS_F0p6.nc
# [2024-05-24 20:55:11,016] {podaac_data_downloader.py:358} INFO - 2024-05-24 20:55:11.016050 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2022/TROPESS_CrIS-JPSS1_L2_Summary_CO_20220627_MUSES_R1p17_FS_F0p6.nc
# [2024-05-24 20:55:11,730] {podaac_data_downloader.py:358} INFO - 2024-05-24 20:55:11.730400 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2022/TROPESS_CrIS-JPSS1_L2_Summary_CO_20220626_MUSES_R1p17_FS_F0p6.nc
# [2024-05-24 20:55:12,275] {podaac_data_downloader.py:358} INFO - 2024-05-24 20:55:12.275253 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2022/TROPESS_CrIS-JPSS1_L2_Summary_CO_20220625_MUSES_R1p17_FS_F0p6.nc
# [2024-05-24 20:55:12,782] {podaac_data_downloader.py:358} INFO - 2024-05-24 20:55:12.782061 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2022/TROPESS_CrIS-JPSS1_L2_Summary_CO_20220624_MUSES_R1p17_FS_F0p6.nc
# [2024-05-24 20:55:13,302] {podaac_data_downloader.py:358} INFO - 2024-05-24 20:55:13.302180 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2022/TROPESS_CrIS-JPSS1_L2_Summary_CO_20220623_MUSES_R1p17_FS_F0p6.nc
# [2024-05-24 20:55:13,824] {podaac_data_downloader.py:358} INFO - 2024-05-24 20:55:13.823946 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2022/TROPESS_CrIS-JPSS1_L2_Summary_CO_20220622_MUSES_R1p17_FS_F0p6.nc
# [2024-05-24 20:55:14,308] {podaac_data_downloader.py:358} INFO - 2024-05-24 20:55:14.308511 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2022/TROPESS_CrIS-JPSS1_L2_Summary_CO_20220621_MUSES_R1p17_FS_F0p6.nc
# [2024-05-24 20:55:14,837] {podaac_data_downloader.py:358} INFO - 2024-05-24 20:55:14.837205 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2022/TROPESS_CrIS-JPSS1_L2_Summary_CO_20220620_MUSES_R1p17_FS_F0p6.nc
# [2024-05-24 20:55:15,397] {podaac_data_downloader.py:358} INFO - 2024-05-24 20:55:15.396796 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2022/TROPESS_CrIS-JPSS1_L2_Summary_CO_20220619_MUSES_R1p17_FS_F0p6.nc
# [2024-05-24 20:55:15,791] {podaac_data_downloader.py:358} INFO - 2024-05-24 20:55:15.791937 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2022/TROPESS_CrIS-JPSS1_L2_Summary_CO_20220618_MUSES_R1p17_FS_F0p6.nc
# [2024-05-24 20:55:16,325] {podaac_data_downloader.py:358} INFO - 2024-05-24 20:55:16.325706 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2022/TROPESS_CrIS-JPSS1_L2_Summary_CO_20220617_MUSES_R1p17_FS_F0p6.nc
# [2024-05-24 20:55:16,823] {podaac_data_downloader.py:358} INFO - 2024-05-24 20:55:16.823098 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2022/TROPESS_CrIS-JPSS1_L2_Summary_CO_20220616_MUSES_R1p17_FS_F0p6.nc
# [2024-05-24 20:55:17,306] {podaac_data_downloader.py:358} INFO - 2024-05-24 20:55:17.306494 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2022/TROPESS_CrIS-JPSS1_L2_Summary_CO_20220615_MUSES_R1p17_FS_F0p6.nc
# [2024-05-24 20:55:17,957] {podaac_data_downloader.py:358} INFO - 2024-05-24 20:55:17.957887 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2022/TROPESS_CrIS-JPSS1_L2_Summary_CO_20220614_MUSES_R1p17_FS_F0p6.nc
# [2024-05-24 20:55:18,662] {podaac_data_downloader.py:358} INFO - 2024-05-24 20:55:18.662383 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2022/TROPESS_CrIS-JPSS1_L2_Summary_CO_20220613_MUSES_R1p17_FS_F0p6.nc
# [2024-05-24 20:55:19,084] {podaac_data_downloader.py:358} INFO - 2024-05-24 20:55:19.084761 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2022/TROPESS_CrIS-JPSS1_L2_Summary_CO_20220612_MUSES_R1p17_FS_F0p6.nc
# [2024-05-24 20:55:19,591] {podaac_data_downloader.py:358} INFO - 2024-05-24 20:55:19.591922 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2022/TROPESS_CrIS-JPSS1_L2_Summary_CO_20220611_MUSES_R1p17_FS_F0p6.nc
# [2024-05-24 20:55:20,101] {podaac_data_downloader.py:358} INFO - 2024-05-24 20:55:20.101880 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2022/TROPESS_CrIS-JPSS1_L2_Summary_CO_20220610_MUSES_R1p17_FS_F0p6.nc
# [2024-05-24 20:55:20,743] {podaac_data_downloader.py:358} INFO - 2024-05-24 20:55:20.743494 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2022/TROPESS_CrIS-JPSS1_L2_Summary_CO_20220609_MUSES_R1p17_FS_F0p6.nc
# [2024-05-24 20:55:21,143] {podaac_data_downloader.py:358} INFO - 2024-05-24 20:55:21.143347 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2022/TROPESS_CrIS-JPSS1_L2_Summary_CO_20220608_MUSES_R1p17_FS_F0p6.nc
# [2024-05-24 20:55:21,729] {podaac_data_downloader.py:358} INFO - 2024-05-24 20:55:21.729829 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2022/TROPESS_CrIS-JPSS1_L2_Summary_CO_20220607_MUSES_R1p17_FS_F0p6.nc
# [2024-05-24 20:55:22,154] {podaac_data_downloader.py:358} INFO - 2024-05-24 20:55:22.154530 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2022/TROPESS_CrIS-JPSS1_L2_Summary_CO_20220606_MUSES_R1p17_FS_F0p6.nc
# [2024-05-24 20:55:22,608] {podaac_data_downloader.py:358} INFO - 2024-05-24 20:55:22.608627 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2022/TROPESS_CrIS-JPSS1_L2_Summary_CO_20220605_MUSES_R1p17_FS_F0p6.nc
# [2024-05-24 20:55:23,050] {podaac_data_downloader.py:358} INFO - 2024-05-24 20:55:23.050734 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2022/TROPESS_CrIS-JPSS1_L2_Summary_CO_20220604_MUSES_R1p17_FS_F0p6.nc
# [2024-05-24 20:55:23,698] {podaac_data_downloader.py:358} INFO - 2024-05-24 20:55:23.698128 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2022/TROPESS_CrIS-JPSS1_L2_Summary_CO_20220603_MUSES_R1p17_FS_F0p6.nc
# [2024-05-24 20:55:24,338] {podaac_data_downloader.py:358} INFO - 2024-05-24 20:55:24.338299 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2022/TROPESS_CrIS-JPSS1_L2_Summary_CO_20220602_MUSES_R1p17_FS_F0p6.nc
# [2024-05-24 20:55:24,801] {podaac_data_downloader.py:358} INFO - 2024-05-24 20:55:24.801732 SUCCESS: https://data.gesdisc.earthdata.nasa.gov/data/TROPESS_Summary/TRPSYL2COCRS1FS.1/2022/TROPESS_CrIS-JPSS1_L2_Summary_CO_20220601_MUSES_R1p17_FS_F0p6.nc
# [2024-05-24 20:55:24,804] {podaac_data_downloader.py:369} INFO - Downloaded Files: 30
# [2024-05-24 20:55:24,804] {podaac_data_downloader.py:370} INFO - Failed Files:     0
# [2024-05-24 20:55:24,804] {podaac_data_downloader.py:371} INFO - Skipped Files:    0
# [2024-05-24 20:55:24,804] {podaac_data_downloader.py:177} INFO - Success Count: 30
# [2024-05-24 20:55:24,967] {podaac_data_downloader.py:186} INFO - END
#
#
# CPU times: user 464 ms, sys: 104 ms, total: 568 ms
# Wall time: 24.1 s

# %% [markdown]
# # Remove .netrc file

# %%
# !rm .netrc

# %% [markdown]
# # Let's read June 2022 daily data products and make a time series and make a monthly average of XCO (colum CO).
# The datasets should be already downloaded in the local directory ./data.
# Please refer to the tutorial about how to download TROPESS datasets from GES DISC.

# %%
# %%time

# Specify date range
start_date = datetime.date(2022, 6, 1)
end_date = datetime.date(2022, 6, 30)

x_col_time_series_2022_june = []

# Loop through the date range and plot Carbon Monoxide for each day
for current_date in pd.date_range(start_date, end_date):
    # Open the netCDF file
    file_date = current_date.strftime("%Y%m%d")
    dataset = Dataset(f'./data/TROPESS_CrIS-JPSS1_L2_Summary_CO_{file_date}_MUSES_R1p17_FS_F0p6.nc', 'r')
    print("reading data from =", file_date)
    
    # Read the data from your variables
    latitude = dataset.variables['latitude'][:]
    longitude = dataset.variables['longitude'][:]
    x_col = dataset.variables['x_col'][:]

    dataset.close()

    # Filter the data for latitude 80S to 80N
    latitude_max = 80.0
    latitude_min = -60.0
    longitude_max = 180.0
    longitude_min = -180.0

    selection_only = np.where(
        (latitude > latitude_min) & (latitude < latitude_max) & 
        (longitude > longitude_min) &(longitude < longitude_max)
    )[0]

    latitude = latitude[selection_only]
    longitude = longitude[selection_only]
    x_col = x_col[selection_only]


    pixel_size_deg = 1.0 # 1 degree resolution

    # Get the grid for the interpolated values
    grid_lat, grid_lon = np.mgrid[-60:81:pixel_size_deg, -180:181:pixel_size_deg]

    # Interpolate the data using griddata
    grid_x_col = griddata((latitude, longitude), x_col, (grid_lat, grid_lon), method='linear', rescale=True)

    # Find the distance to the nearest original point for each point in the interpolated grid
    tree = cKDTree(np.vstack((latitude, longitude)).T)
    dist, _ = tree.query(np.vstack((grid_lat.ravel(), grid_lon.ravel())).T)

    # Reshape the distance array to have the same shape as the x_col grid
    dist_grid = dist.reshape(grid_x_col.shape)

    # Mask the interpolated values that are too far from any original point
    max_distance_degrees = 3.0
    grid_x_col[dist_grid > max_distance_degrees] = np.nan
    
    x_col_time_series_2022_june.append(grid_x_col)
    

x_col_time_series_2022_june = np.array(x_col_time_series_2022_june)    
print(x_col_time_series_2022_june.shape)
x_col_month_mean_2022 = np.mean(x_col_time_series_2022_june, axis=0)
print("X_col_month_mean_shape = ", x_col_month_mean_2022.shape)
# Out:
# reading data from = 20220601
# reading data from = 20220602
# reading data from = 20220603
# reading data from = 20220604
# reading data from = 20220605
# reading data from = 20220606
# reading data from = 20220607
# reading data from = 20220608
# reading data from = 20220609
# reading data from = 20220610
# reading data from = 20220611
# reading data from = 20220612
# reading data from = 20220613
# reading data from = 20220614
# reading data from = 20220615
# reading data from = 20220616
# reading data from = 20220617
# reading data from = 20220618
# reading data from = 20220619
# reading data from = 20220620
# reading data from = 20220621
# reading data from = 20220622
# reading data from = 20220623
# reading data from = 20220624
# reading data from = 20220625
# reading data from = 20220626
# reading data from = 20220627
# reading data from = 20220628
# reading data from = 20220629
# reading data from = 20220630
# (30, 141, 361)
# X_col_month_mean_shape =  (141, 361)
# CPU times: user 32.6 s, sys: 664 ms, total: 33.3 s
# Wall time: 25.5 s

# %% [markdown]
# # Let's make a global map of the June 2022 averaged XCO using Basemap.

# %%
# %%time

    # Calculate width and height
    aspect_ratio = (longitude_max - longitude_min) / (latitude_max - latitude_min)
    w = 3600; h = w / aspect_ratio

    # Specify figure size (in inches)
    dpi = 300; 
    plt.figure(figsize=(w / dpi, h / dpi))  

    # Create a basemap instance
    m = Basemap(projection='cyl', resolution='l',
                llcrnrlat=-60, urcrnrlat=80,  # set latitude limits to -80 and 80
                llcrnrlon=-180, urcrnrlon=180)  # set longitude limits to -180 and -180

    m.drawmapboundary(fill_color='black')
    m.drawcoastlines(linewidth=0.3, color='white')
    m.drawcountries(linewidth=0.2, color='white')
    #m.drawstates(linewidth=0.2, color='white')

    # Draw parallels (latitude lines) and meridians (longitude lines)
    parallels = np.arange(-60., 81., 20.)
    m.drawparallels(parallels, labels=[True,False,False,False], linewidth=0.3)

    meridians = np.arange(-180., 181., 30.)
    m.drawmeridians(meridians, labels=[False,False,False,True], linewidth=0.3)
    
    pixel_size_deg = 1.0 # 1 degree resolution

    # Get the grid for the interpolated values
    grid_lat, grid_lon = np.mgrid[-60:81:pixel_size_deg, -180:181:pixel_size_deg]
    
    # Plot the interpolated data using pcolormesh instead of scatter
    sc = m.pcolormesh(grid_lon, grid_lat, x_col_month_mean_2022, latlon=True, cmap='jet', alpha=0.7, vmin=60.0, vmax=200.0, shading='auto')
    
    # Add a colorbar
    cbar = m.colorbar(sc, location='bottom', pad="10%")
    cbar.set_label('Column-averaged dry-air mixing ratio of carbon monoxide from the surface to Top of Atmosphere (TOA), ppbv')

    # set plot title
    title_date = current_date.strftime("%b-%Y")
    title_min = np.nanmin(x_col_month_mean_2022)
    title_max = np.nanmax(x_col_month_mean_2022)
    plt.title(f'TROPESS - CrIS JPSS-1 - Carbon Monoxide Column (XCO) Month Average - June 2022')
    #\nMin: {title_min:.01f}, Max: {title_max:.01f} ppbv')

    # Save figure to PNG file
    plt.savefig(f'./images_average/TROPESS_Canadian-Fires_CrIS-JPSS-1_XCO_June_2022_month_average.png', dpi=dpi, bbox_inches='tight')

    plt.show()
    plt.close()
# Out:
# CPU times: user 1.48 s, sys: 45.3 ms, total: 1.53 s
# Wall time: 1.98 s

# %% [markdown]
# # Let's get the difference between June 2023 XCO and June 2022 XCO and plot the difference in a global map.

# %%
# %%time

    x_col_diff_month_average = x_col_month_mean_2023 - x_col_month_mean_2022
    #print (x_col_diff_month_average.shape)
 
    # Calculate width and height
    aspect_ratio = (longitude_max - longitude_min) / (latitude_max - latitude_min)
    w = 3600; h = w / aspect_ratio

    # Specify figure size (in inches)
    dpi = 300; 
    plt.figure(figsize=(w / dpi, h / dpi))  

    # Create a basemap instance
    m = Basemap(projection='cyl', resolution='l',
                llcrnrlat=-60, urcrnrlat=80,  # set latitude limits to -80 and 80
                llcrnrlon=-180, urcrnrlon=180)  # set longitude limits to -180 and -180

    m.drawmapboundary(fill_color='black')
    m.drawcoastlines(linewidth=0.3, color='white')
    m.drawcountries(linewidth=0.2, color='white')
    #m.drawstates(linewidth=0.2, color='white')


    # Draw parallels (latitude lines) and meridians (longitude lines)
    parallels = np.arange(-60., 81., 20.)
    m.drawparallels(parallels, labels=[True,False,False,False], linewidth=0.3)

    meridians = np.arange(-180., 181., 30.)
    m.drawmeridians(meridians, labels=[False,False,False,True], linewidth=0.3)
    
    pixel_size_deg = 1.0 # 1 degree resolution

    # Get the grid for the map
    grid_lat, grid_lon = np.mgrid[-60:81:pixel_size_deg, -180:181:pixel_size_deg]

    
    # Plot the difference data using pcolormesh instead of scatter
    sc = m.pcolormesh(grid_lon, grid_lat, x_col_diff_month_average, latlon=True, cmap='seismic', alpha=0.8, vmin=-60, vmax=60.0, shading='auto')

    # Add a colorbar
    cbar = m.colorbar(sc, location='bottom', pad="10%")
    cbar.set_label('Column-averaged dry-air mixing ratio of carbon monoxide from the surface to Top of Atmosphere (TOA), ppbv')

    # set plot title
    #title_date = current_date.strftime("%b-%Y")
    title_min = np.nanmin(x_col_diff_month_average)
    title_max = np.nanmax(x_col_diff_month_average)
    plt.title(f'TROPESS - CrIS JPSS-1 - Carbon Monoxide Column (XCO) June Difference (2023 - 2022)')
    #' \nMin: {title_min:.01f}, Max: {title_max:.01f} ppbv')

    # Save figure to PNG file
    plt.savefig(f'./images_average/TROPESS_Canadian-Fires_CrIS-JPSS-1_XCO_2023_2022_June_month_diff.png', dpi=dpi, bbox_inches='tight')

    plt.show()
    plt.close()
# Out:
# CPU times: user 1.44 s, sys: 35.1 ms, total: 1.47 s
# Wall time: 1.66 s

# %% [markdown]
# # Let's calculate the average difference of xco in the Northeast part of North America (latitude = [40,60] and longitude [-90,-60]].)

# %%
# %%time

    latitude_min=40
    latitude_max=60
    longitude_min=-90
    longitude_max=-60
    
    small_selection = np.where(
        (grid_lat > latitude_min) & (grid_lat < latitude_max) & 
        (grid_lon > longitude_min) &(grid_lon < longitude_max)
    )

    #print (small_selection)
    grid_lat_small = grid_lat[small_selection]
    grid_lon_small = grid_lon[small_selection]
    x_col_diff_small = x_col_diff_month_average[small_selection]
    
    
    x_col_diff_mean = x_col_diff_small.mean()
    print("Northeast America XCO increase from 2022 June to 2023 June = ", "{0:.2f}".format(x_col_diff_mean), 'ppbv')
# Out:
# Northeast America XCO increase from 2022 June to 2023 June =  20.44 ppbv
# CPU times: user 1.13 ms, sys: 0 ns, total: 1.13 ms
# Wall time: 1.78 ms

# %% [markdown]
# # Let's write the monthly average data and difference data in a NetCDF file for future use.

# %%
# %%time

longitude_1D = np.arange(-180,181,1.0)
latitude_1D = np.arange(-60,81,1.0)

#print('length of latitude =', len(latitude_1D))
#print('length of longitude =', len(longitude_1D))

ncout = Dataset('TROPESS_CRIS_JPSS1_2022_2023_June_XCO.nc', mode='w', format='NETCDF4_CLASSIC')

ncout.createDimension('latitude', len(latitude_1D))
ncout.createDimension('longitude', len(longitude_1D))

lonvar = ncout.createVariable('longitude','float32',('longitude'))
lonvar[:] = longitude_1D

latvar = ncout.createVariable('latitude','float32',('latitude'))
latvar[:] = latitude_1D

myvar = ncout.createVariable('xco_2022_June','float32',('latitude','longitude'))
myvar.setncattr('units','ppbv')
myvar[:] = x_col_month_mean_2022;

myvar = ncout.createVariable('xco_2023_June','float32',('latitude','longitude'))
myvar.setncattr('units','ppbv')
myvar[:] = x_col_month_mean_2023;

myvar = ncout.createVariable('xco_diff','float32',('latitude','longitude'))
myvar.setncattr('units','ppbv')
myvar[:] = x_col_diff_month_average;
ncout.close();
# Out:
# CPU times: user 5.02 ms, sys: 4.03 ms, total: 9.05 ms
# Wall time: 8.74 ms
